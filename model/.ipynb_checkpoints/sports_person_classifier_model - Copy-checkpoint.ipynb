# %%
import numpy as np
import cv2
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# img = cv2.imread('/content/drive/MyDrive/Excersice ML/model/images_dataset/maria_sharapova/sharapova-hits-the-practice-courts-and-met-ball-kids.jpg')
img = cv2.imread('/content/drive/MyDrive/Excersice ML/model/images_dataset/maria_sharapova/sharapova-hits-the-practice-courts-and-met-ball-kids.jpg')

img.shape
# img = cv2.imread()
# Out:
# (555, 700, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (555, 700)

# %%
plt.imshow(gray,cmap='gray')

# %%
gray
# Out:
# array([[175, 175, 175, ..., 176, 175, 174],
#        [175, 175, 175, ..., 177, 175, 174],
#        [175, 175, 175, ..., 177, 176, 174],
#        ...,
#        [ 84,  87,  88, ..., 113, 113, 113],
#        [ 88,  89,  90, ..., 113, 113, 113],
#        [ 93,  91,  91, ..., 112, 112, 112]], dtype=uint8)

# %%
face_cascade = cv2.CascadeClassifier('/content/drive/MyDrive/Excersice ML/model/opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('/content/drive/MyDrive/Excersice ML/model/opencv/haarcascades/haarcascade_eye.xml')
# https://www.geeksforgeeks.org/face-detection-using-cascade-classifier-using-opencv-python/
# https://stackoverflow.com/questions/36218385/parameters-of-detectmultiscale-in-opencv-using-python
faces = face_cascade.detectMultiScale(gray,1.3,5)
faces
# Out:
# array([[352,  38, 233, 233]], dtype=int32)

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (352, 38, 233, 233)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
  face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
  roi_gray = gray[y:y+h,x:x+w]
  roi_color = face_img[y:y+h,x:x+w]
  eyes = eye_cascade.detectMultiScale(roi_gray)
  for(ex,ey,ew,eh) in eyes:
    cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)

plt.figure()
plt.imshow(face_img , cmap='gray')
plt.show()

# %%
# gray[y:y+h,x:x+w]

# %%
# face_img

# %%
# %matplotlib inline
plt.imshow(roi_gray,cmap='gray')

# %%
# %matplotlib inline
plt.imshow(roi_color,cmap='gray')

# %%
def get_cropped_image_if_2_eyes(image_path):
  img = cv2.imread(image_path)
  gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
  faces = face_cascade.detectMultiScale(gray,1.2,5)
  for(x,y,w,h) in faces:
    roi_gray = gray[y:y+h,x:x+w]
    roi_color = img[y:y+h,x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    if(len(eyes)>=2):
      return roi_color

# %%
cropped_image = get_cropped_image_if_2_eyes('/content/drive/MyDrive/Excersice ML/model/images_dataset/maria_sharapova/sharapova-hits-the-practice-courts-and-met-ball-kids.jpg')
plt.imshow(cropped_image)

# %%
# cropped_image = get_cropped_image_if_2_eyes('/content/drive/MyDrive/Excersice ML/model/images_dataset/maria_sharapova/3-681.jpg')
# # plt.imshow(cropped_image)
# cropped_image

# %%
path_to_data="/content/drive/MyDrive/Excersice ML/model/images_dataset"
path_to_cr_data="/content/drive/MyDrive/Excersice ML/model/images_dataset/cropped/"

# %%
# import shutil
# if os.path.exists(path_to_cr_data):
#   shutil.rmtree(path_to_cr_data) #removing folder if exists
# os.mkdir(path_to_cr_data) # create folder

# %%
import os
img_dirs = []
for entry in os.scandir("/content/drive/MyDrive/Excersice ML/model/images_dataset"):
  if entry.is_dir():
    img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['/content/drive/MyDrive/Excersice ML/model/images_dataset/maria_sharapova',
#  '/content/drive/MyDrive/Excersice ML/model/images_dataset/virat_kohli',
#  '/content/drive/MyDrive/Excersice ML/model/images_dataset/lionel_messi',
#  '/content/drive/MyDrive/Excersice ML/model/images_dataset/roger_federer',
#  '/content/drive/MyDrive/Excersice ML/model/images_dataset/serena_williams',
#  '/content/drive/MyDrive/Excersice ML/model/images_dataset/cropped']

# %%
import shutil
if os.path.exists(path_to_cr_data):
  shutil.rmtree(path_to_cr_data) #removing folder if exists
os.mkdir(path_to_cr_data) # create folder

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    print(celebrity_name)
    celebrity_file_names_dict[celebrity_name] = []

    for entry in os.scandir(img_dir):
      roi_color = get_cropped_image_if_2_eyes(entry.path)
      if roi_color is not None:
        cropped_folder = path_to_cr_data + celebrity_name
        if not os.path.exists(cropped_folder):
          os.makedirs(cropped_folder)
          cropped_image_dirs.append(cropped_folder)
          print("Generating cropped images in folder: ",cropped_folder)

        cropped_file_name = celebrity_name + str(count) + ".png"
        cropped_file_path = cropped_folder + "/" + cropped_file_name

        cv2.imwrite(cropped_file_path,roi_color)
        celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
        count +=1
# Out:
# maria_sharapova
# Generating cropped images in folder:  /content/drive/MyDrive/Excersice ML/model/images_dataset/cropped/maria_sharapova
# virat_kohli
# Generating cropped images in folder:  /content/drive/MyDrive/Excersice ML/model/images_dataset/cropped/virat_kohli
# lionel_messi
# Generating cropped images in folder:  /content/drive/MyDrive/Excersice ML/model/images_dataset/cropped/lionel_messi
# roger_federer
# Generating cropped images in folder:  /content/drive/MyDrive/Excersice ML/model/images_dataset/cropped/roger_federer
# serena_williams
# Generating cropped images in folder:  /content/drive/MyDrive/Excersice ML/model/images_dataset/cropped/serena_williams
# cropped
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-41-1c8276020c0f> in <module>()
#       8
#       9     for entry in os.scandir(img_dir):
# ...

# %%
import numpy
import pywt
import cv2

def w2d(img,mode='haar',level=1):
  imArray = img

  imArray = cv2.cvtColor(imArray,cv2.COLOR_RGB2GRAY)
  imArray = np.float32(imArray)
  imArray /= 255

  coeffs=pywt.wavedec2(imArray,mode,level=level)

  coeffs_H=list(coeffs)
  coeffs_H[0] *=0;

  imArray_H=pywt.waverec2(coeffs_H,mode)
  imArray_H *= 255;
  imArray_H = np.uint8(imArray_H)

  return imArray_H

# %%
im_har = w2d(cropped_image,'db1',5)
plt.imshow(im_har,cmap='gray')

# %%
celebrity_file_names_dict.pop('cropped')
celebrity_file_names_dict
# Out:
# {'lionel_messi': ['/content/drive/MyDrive/Excersice ML/model/images_dataset/cropped/lionel_messi/lionel_messi1.png',
#   '/content/drive/MyDrive/Excersice ML/model/images_dataset/cropped/lionel_messi/lionel_messi2.png',
#   '/content/drive/MyDrive/Excersice ML/model/images_dataset/cropped/lionel_messi/lionel_messi3.png',
#   '/content/drive/MyDrive/Excersice ML/model/images_dataset/cropped/lionel_messi/lionel_messi4.png',
#   '/content/drive/MyDrive/Excersice ML/model/images_dataset/cropped/lionel_messi/lionel_messi5.png',
#   '/content/drive/MyDrive/Excersice ML/model/images_dataset/cropped/lionel_messi/lionel_messi6.png',
#   '/content/drive/MyDrive/Excersice ML/model/images_dataset/cropped/lionel_messi/lionel_messi7.png',
#   '/content/drive/MyDrive/Excersice ML/model/images_dataset/cropped/lionel_messi/lionel_messi8.png',
#   '/content/drive/MyDrive/Excersice ML/model/images_dataset/cropped/lionel_messi/lionel_messi9.png',
# ...

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
  class_dict[celebrity_name] = count
  count = count + 1
class_dict
# Out:
# {'lionel_messi': 2,
#  'maria_sharapova': 0,
#  'roger_federer': 3,
#  'serena_williams': 4,
#  'virat_kohli': 1}

# %%
X = []
y= []
for celebrity_name , training_files in celebrity_file_names_dict.items():
  for training_image in training_files:
    img = cv2.imread(training_image)
    if img is None:
      continue
    scalled_raw_img = cv2.resize(img,(32,32))
    img_har = w2d(img,'db1',5)
    scalled_img_hr = cv2.resize(img_har,(32,32))
    combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_hr.reshape(32*32,1)))
    X.append(combined_img)
    y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
len(y)
# Out:
# 168

# %%
X[0]
# Out:
# array([[113],
#        [147],
#        [177],
#        ...,
#        [228],
#        [237],
#        [240]], dtype=uint8)

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (168, 4096)

# %%
X[0]
# Out:
# array([113., 147., 177., ..., 228., 237., 240.])

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
pipe = Pipeline([('scaler',StandardScaler()),('svc',SVC(kernel='rbf',C=10))])
pipe.fit(X_train,y_train)
pipe.score(X_test,y_test)
# Out:
# 0.8095238095238095

# %%
print(classification_report(y_test,pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      1.00      0.82         7
#            1       0.92      0.92      0.92        12
#            2       0.88      0.70      0.78        10
#            3       0.67      0.67      0.67         6
#            4       0.83      0.71      0.77         7
#
#     accuracy                           0.81        42
#    macro avg       0.80      0.80      0.79        42
# weighted avg       0.82      0.81      0.81        42

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm':{
        'model': svm.SVC(gamma='auto',probability=True),
        'params': {
            'svc__C':[1,10,100,1000],
            'svc__kernel':['rbf','linear']
        }
    },
    'random_forest':{
        'model': RandomForestClassifier(),
        'params': {
            'randomforestclassifier__n_estimators':[1,5,10]
        }
    },
    'logistic_regression':{
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params':{
            'logisticregression__C':[1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
  pipe = make_pipeline(StandardScaler(),mp['model'])
  clf = GridSearchCV(pipe,mp['params'],cv=5,return_train_score=False)
  clf.fit(X_train,y_train)
  scores.append({
      'model': algo,
      'best_score': clf.best_score_ ,
      'best_params': clf.best_params_
  })
  best_estimators[algo] = clf.best_estimator_

df=pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  ...                                   best_params
# 0                  svm  ...        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1        random_forest  ...  {'randomforestclassifier__n_estimators': 10}
# 2  logistic_regression  ...                  {'logisticregression__C': 5}
#
# [3 rows x 3 columns]

# %%
best_estimators
# Out:
# {'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=5, solver='liblinear'))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.9047619047619048

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.8809523809523809

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.7142857142857143

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,best_clf.predict(X_test))
cm
# Out:
# array([[ 7,  0,  0,  0,  0],
#        [ 0, 12,  0,  0,  0],
#        [ 1,  0,  8,  1,  0],
#        [ 0,  1,  0,  5,  0],
#        [ 0,  0,  0,  1,  6]])

# %%
import seaborn as sns
plt.figure(figsize=(10,7))
sns.heatmap(cm,annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'lionel_messi': 2,
#  'maria_sharapova': 0,
#  'roger_federer': 3,
#  'serena_williams': 4,
#  'virat_kohli': 1}

# %%
# !pip install joblib
import joblib
joblib.dump(best_clf,'saved_model.pkl')
# Out:
# ['saved_model.pkl']

# %%
import json
with open("class_dictionary.json","w") as f:
  f.write(json.dumps(class_dict))
